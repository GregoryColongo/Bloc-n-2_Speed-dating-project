# %%
# Import librairies

! pip install plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = "iframe_connected"
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Speed Dating Part 1
# Start exploring the dataset with pandas to extract some statistics

# %%
# Retrieving of dataset

sd=pd.read_csv('Speed Dating Data.csv', encoding="ISO-8859-1")

# %%
# Some statistics

print("------------------------------------------")
print("First rows : ")
print()
display(sd.head())
print("------------------------------------------")
print("Size of dataset : {}".format(sd.shape))
print("------------------------------------------")
print("Global description of dataset :")
print("------------------------------------------")
display(sd.describe(include="all"))
print("------------------------------------------")
print("Percentage of missing values: ")
print("------------------------------------------")
print()
display(100*sd.isnull().sum()/sd.shape[0])
print("------------------------------------------")
# Out:
# ------------------------------------------
# First rows :
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# ...

# %%
# There are 552 uniques participants
# Lot of columns are with NaN status, so I decided to drop them with the following rule : missing values rate > 60 %

# %%
# Creation of new dataset sd2 with dropped columns

sd2 = sd.loc[:,100*sd.isnull().sum()/sd.shape[0]<60] 
sd2.head()

# It remains 162 columns
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    sinc1_3  intel1_3  fun1_3  amb1_3  shar1_3  attr3_3  sinc3_3  intel3_3  \
# 0     20.0      20.0    15.0    15.0     15.0      5.0      7.0       7.0
# 1     20.0      20.0    15.0    15.0     15.0      5.0      7.0       7.0
# 2     20.0      20.0    15.0    15.0     15.0      5.0      7.0       7.0
# 3     20.0      20.0    15.0    15.0     15.0      5.0      7.0       7.0
# 4     20.0      20.0    15.0    15.0     15.0      5.0      7.0       7.0
#
#    fun3_3  amb3_3
# 0     7.0     7.0
# ...

# %%
# Relevant features (features selection): 

# It's better to rewrite title of features in order to be more understandable
# renaming choosen columns

sd2.rename(columns={"iid":"unique ID",
                    "gender":"Male/Female",
                    "match":"match",            
                    "samerace":"same race",
                    "age_o":"age partner",
                    "race_o":"race partner",
                    "dec_o":"decision partner",
                    "attr_o":"rating partner night of event",
                    "imprace":"importance same racial/ethn",
                    "imprelig":"importance same relig",
                    "from":"come from",
                    "goal":"goal of partner",
                    "career_c":"career code",
                    "satis_2":"degr satisfaction after T1"
                    },inplace=True)
sd2.head()
# Out:
# /tmp/ipykernel_107/2421581546.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    unique ID   id  Male/Female  idg  condtn  wave  round  position  positin1  \
# 0          1  1.0            0    1       1     1     10         7       NaN
# 1          1  1.0            0    1       1     1     10         7       NaN
# 2          1  1.0            0    1       1     1     10         7       NaN
# 3          1  1.0            0    1       1     1     10         7       NaN
# 4          1  1.0            0    1       1     1     10         7       NaN
#
#    order  ...  sinc1_3  intel1_3  fun1_3  amb1_3  shar1_3  attr3_3  sinc3_3  \
# 0      4  ...     20.0      20.0    15.0    15.0     15.0      5.0      7.0
# 1      3  ...     20.0      20.0    15.0    15.0     15.0      5.0      7.0
# ...

# %%
#Selection and reduction of columns 

col_ok = ["unique ID",
          "Male/Female",
          "match",
          "same race",
          "age partner",
          "race partner",
          "decision partner",
          "rating partner night of event",
          "importance same racial/ethn",
          "importance same relig",
          "come from",
          "goal of partner",
          "career code",
          "degr satisfaction after T1"]
speedat = sd2.loc[:,col_ok]
speedat.head()
# Out:
#    unique ID  Male/Female  match  same race  age partner  race partner  \
# 0          1            0      0          0         27.0           2.0
# 1          1            0      0          0         22.0           2.0
# 2          1            0      1          1         22.0           4.0
# 3          1            0      1          0         23.0           2.0
# 4          1            0      1          0         24.0           3.0
#
#    decision partner  rating partner night of event  \
# 0                 0                            6.0
# 1                 0                            7.0
# 2                 1                           10.0
# 3                 1                            7.0
# 4                 1                            8.0
#
#    importance same racial/ethn  importance same relig come from  \
# 0                          2.0                    4.0   Chicago
# 1                          2.0                    4.0   Chicago
# ...

# %%
race_replacement={1:"Black/African American",
                 2: "European/Caucasion-American",
                 3: "Latino/Hispanic American",
                 4: "Asian/Pacific Islander/Asian-American",
                 5: "Native American",
                 6: "Other"}

goal_replacement={1:"Seemed like a fan night out",
                 2: "To meet new people",
                 3: "To get a date",
                 4:"Looking for serious relationship",
                 5:"To say I did it",
                 6: "Other"}

career_replacement={1: "Lawyer",
                   2:  "Academic / Research",
                   3:  "Psychologist",
                   4:  "Doctor/Medicine",
                   5:  "Engineer",
                   6:  "Creative Arts/ Entertainment",
                   7:  "Banking / Consulting /Finance / Marketing/ Business /CEO/ Entrepreneur / Admin",
                   8:  "Real Estate",
                   9:  "International /Humanitarian Affairs",
                   10:  "Undecided",
                   11:  "Social Work",
                   12:  "Speech Pathology",
                   13:  "Politics",
                   14:  "Pro Sports / Athletics",
                   15:  "Other",
                   16:  "Journalism",
                   17:  "Architecture"}

# %%
speedat["Male/Female"].replace({0:"Female",1:"Male"}, inplace=True)
speedat["race partner"].replace(race_replacement, inplace=True)
speedat["career code"].replace(career_replacement, inplace=True)
speedat["goal of partner"].replace(goal_replacement, inplace=True)

# %%
speedat.head()
# Out:
#    unique ID Male/Female  match  same race  age partner  \
# 0          1      Female      0          0         27.0
# 1          1      Female      0          0         22.0
# 2          1      Female      1          1         22.0
# 3          1      Female      1          0         23.0
# 4          1      Female      1          0         24.0
#
#                             race partner  decision partner  \
# 0            European/Caucasion-American                 0
# 1            European/Caucasion-American                 0
# 2  Asian/Pacific Islander/Asian-American                 1
# 3            European/Caucasion-American                 1
# 4               Latino/Hispanic American                 1
#
#    rating partner night of event  importance same racial/ethn  \
# 0                            6.0                          2.0
# 1                            7.0                          2.0
# 2                           10.0                          2.0
# ...

# %%
# Manage the missing values

print("Percentage of missing values: ")
print("------------------------------------------")
print()
display(100*speedat.isnull().sum()/speedat.shape[0])
print("------------------------------------------")
print("Global description of dataset :")
print("------------------------------------------")
display(speedat.describe(include="all"))
# Out:
# Percentage of missing values:
# ------------------------------------------
# unique ID                         0.000000
# Male/Female                       0.000000
# match                             0.000000
# same race                         0.000000
# age partner                       1.241346
# race partner                      0.871330
# decision partner                  0.000000
# rating partner night of event     2.530437
# importance same racial/ethn       0.942946
# importance same relig             0.942946
# come from                         0.942946
# goal of partner                   0.942946
# career code                       1.647171
# degr satisfaction after T1       10.921461
# dtype: float64
# ------------------------------------------
# Global description of dataset :
# ------------------------------------------
#           unique ID Male/Female        match    same race  age partner  \
# count   8378.000000        8378  8378.000000  8378.000000  8274.000000
# ...

# %%
# Missing values are managed upstream with pandas for degree of satisfaction

speedat.loc[:,'degr satisfaction after T1'] = speedat['degr satisfaction after T1'].fillna(speedat['degr satisfaction after T1'].median())

# %%
display(100*speedat.isnull().sum()/speedat.shape[0])
# Out:
# unique ID                        0.000000
# Male/Female                      0.000000
# match                            0.000000
# same race                        0.000000
# age partner                      1.241346
# race partner                     0.871330
# decision partner                 0.000000
# rating partner night of event    2.530437
# importance same racial/ethn      0.942946
# importance same relig            0.942946
# come from                        0.942946
# goal of partner                  0.942946
# career code                      1.647171
# degr satisfaction after T1       0.000000
# dtype: float64

# %% [markdown]
# # Speed Dating Part 2
# Let's try to produce our first visualisations with Seaborn. Based on the exploration you realized,
# try to find good representations of the dataset that allow to summarize
# some statistics as well as relationships between variables.

# %%
# Heatmap for correlations and some basics vizualisations

corr = speedat.corr() 
f, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# we have some coorelations between 

#             "decision partner" / match"
#             "importance same race/ importance same religion"
#             "decision partner /rating of partner"

# %%
sns.lmplot(x='rating partner night of event', y='decision partner', data=speedat , logistic = True)

# Strong coorelation between these 2 features with the logistic regression graph
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning:
#
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
sns.lmplot(x='importance same racial/ethn', y='importance same relig', data=speedat )

# %%
sns.lmplot(x='age partner', y='decision partner', data=speedat , logistic = True)

# Age does not lead the decision partner

# %%
sns.displot(speedat['age partner'])

# Most of participants are bewteen 20 and 35 years old

# %%
sns.boxplot(speedat['age partner'],color="red") 

# Some outliers after 35 years
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='age partner'>

# %%
sns.countplot(speedat['Male/Female'])

# Exact parity
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Male/Female', ylabel='count'>

# %% [markdown]
# ### Speed Dating - Part 3 ###
#
#
#
# Continue exploring the Speed Dating dataset. You can use Seaborn and/or Matplotlib in case you want to master the rendering of the visualizations : for example, try to superimpose different plots, change the color palettes, add some texts, etc,...
#
# One thing to remember : in EDA, there's not one only way to highlight relevant information ! And there are choices to be made about the aspects you'd like to explore in this dataset, so don't hesitate to be creative :-)

# %%
sns.catplot(y="goal of partner", col="Male/Female",
                data=speedat, kind="count",
                 height=10, aspect=1);

# To get a Date (3) is not the priority for both gender
# the two mains goals are "seemed like a fun night out" and "to meet new people"

# %%
sns.catplot(y="career code", col="Male/Female",
                data=speedat, kind="count",
                 height=10, aspect=0.8);

# Percentage of people with match yes = 1 / No = 0# Men are Bank/finance jobs mainly
# Women are Academic/Research mainly

# %%
# Number of people with match yes = 1 / No = 0
# 16.5 % are ok
sns.color_palette("Set3")
sns.countplot(speedat['match'], palette='Set3')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='match', ylabel='count'>

# %%
# Importance of same racial group
imprac = speedat.groupby('race partner')['importance same racial/ethn'].mean()
imprac
# Out:
# race partner
# Asian/Pacific Islander/Asian-American    3.744648
# Black/African American                   3.685990
# European/Caucasion-American              3.818046
# Latino/Hispanic American                 3.744292
# Other                                    3.813953
# Name: importance same racial/ethn, dtype: float64

# %%
#Pie Chart for same racial group feature

label = ['Asian/Pacific Islander/Asian-American','Black/African American ','European/Caucasion-American','Latino/Hispanic American','Other']
plt.pie(imprac, labels=label, autopct='%1.1f%%')
plt.title("Importance of Same Racial group per race partner") 
plt.show()

# None race partner have an high or low mean, everybody is about 20 %

# %%
# Importance of same religion
imprel = speedat.groupby('race partner')['importance same relig'].mean()
imprel
# Out:
# race partner
# Asian/Pacific Islander/Asian-American    3.601937
# Black/African American                   3.562802
# European/Caucasion-American              3.720334
# Latino/Hispanic American                 3.605784
# Other                                    3.494186
# Name: importance same relig, dtype: float64

# %%
#Pie Chart for same religion feature

label = ['Asian/Pacific Islander/Asian-American','Black/African American ','European/Caucasion-American','Latino/Hispanic American','Other']
plt.pie(imprel, labels=label, autopct='%1.1f%%')
plt.title("Importance of Same Religion group per race partner") 
plt.show()

# Same case as hereabove about religion

# %% [markdown]
# ### Speed Dating - Part 4 ###
#
# Let's finalize our project by adding some interactivity to it ! Try using Plotly to make at least one interactive graph.

# %%
# Plotly vizualisation

fig = px.scatter(speedat, x = "age partner", y = "rating partner night of event", color = "age partner", trendline = "ols")
fig.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning:
#
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#-----------
# In conclusion, we have no strong correlation enabling to see what could influence 
# the decision of a seconde date for a new speed dating round.
#-----------
